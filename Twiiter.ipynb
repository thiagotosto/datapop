# %%
import tweepy
from pymongo import MongoClient

# %%
consumer_key="jHM5NQ2laLIUvSftKY7ollzCR"
consumer_secret="EaMcEGRhweXaxGdGHiBCkQELJ3k2pRR8G6twANblgr7CJhcJun"
access_token="236888293-RAEsy7oTqFtEpUXzG0fn06ioaTjcG700OlYOxzZq"
access_token_secret="i0lSrUk0RAPUUMTKWjzrPG4uEtepqy37Y6pK95U5BwvNy"

# %%
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

api = tweepy.API(auth)

public_tweets = api.home_timeline()

user = api.get_user('maurocezar', tweet_mode="extended")

# %%
print(user.screen_name)
print(user.followers_count)
# Out:
# maurocezar
# 843329

# %%
for tweet in user.timeline():
    print(tweet.text)
# Out:
# RT @c_arreguy: Desde o 0 x 3 para o Atlético-PR, a 11/7/2016, quando Tite foi ao Mineirão ver Fábio e viu Weverton, o Cruzeiro, ainda dirig…
# RT @ricardospinelli: Jogadores com mais assistências no Brasileirão desde 2015:
# 40   Dudu (@Palmeiras)&lt;&lt;
# 25   Gustavo Scarpa (@Palmeiras/@F…
# No ar o Linha de Passe ao vivo na ESPN Brasil. Vamos nessa falar do incrível Fluminense 4-1 Cruzeiro, do atropelame… https://t.co/pmUORs4FsV
# Alguém vai perguntar ao Abel na coletiva de imprensa se o estádio Independência é o mais bonito de Minas Gerais?
# Segundo o Atlético, NÃO há negociação com o treinador português Jorge Jesus
# Logo após Atlético x Flamengo e Palmeiras x Santos, ou seja, lá pelas 21h, tem Linha de Passe ao vivo na ESPN Brasi… https://t.co/LPOvRi7tEu
# Fluminense goleia Cruzeiro por 4-1. Placar de finalizações nos dois jogos entre as duas equipes: 40-4! https://t.co/33EcyT5uLA
# @DiegoPreviatelo 👍🏻
# Hoje, logo após Atlético x Flamengo e Palmeiras x Santos, ou seja, lá pelas 21h, tem Linha de Passe ao vivo na ESPN… https://t.co/sebZyC4v5T
# 🎵 Racing es mi alegria
# Por vos dejo la vida
# La quiebra tampoco el descenso
# Nada puede
# Con el sentimiento que si… https://t.co/HxPjHWpNco
# A principal delas, "Jurabas tu", que a hinchada do Racing canta assim:
#
# https://t.co/bOB9lpBw1T
# Ele era de Santa Fé, como sua banda, hincha do Union e responsável por sucessos que foram levados pelos torcedores… https://t.co/uTq8QCh1se
# Segue o 🧵... Morreu de ataque cardíaco Juan Carlos “Banana” Mascheroni, líder e “cantante” da banda de cumbia  Los… https://t.co/VTSTQgeF9e
# 🤔 https://t.co/fjviKmrZco
# @CassyusAhtip2c Sei que você é daqueles que discorda 100% das vezes, insistente, cansativo. Adeus
# @712Rochapousada é uma sequência de tuítes, cara, tem que ler a thread
# @PeckAlmeida esse é o trabalho. abs
# @HamiltonCalilJr Quem disse que foi ruim? Fez 47 jogos e 20 gols pelo Manchester City na temporada, 4 no Burton (9… https://t.co/wSmqzCxbdC
# Os 43 jogos, as 69 finalizações de Lucas Moura e seus 15 gols pelo Tottenham na temporada em partidas pela Premier… https://t.co/xjRSzEoFHQ
# Agora o posicionamento de Lucas Moura no Tottenham de Pochettino. Incrível que depois de mostrar poder de decisão e… https://t.co/j64G0SEWXa

# %%
#len(api.search(q="@fredgol9", count=1000, tweet_mode="extended", since='2018-01-01'))
for b in api.search(q="@fredgol9", count=1000, tweet_mode="extended", since='2018-01-01'):
    print(b.full_text)

#api.search(q="bruno henrique", tweet_mode="extended").full_text
# Out:
# @Danilo65049691 @bernardofrancas @leopancierii @fredgol9 rel4x4, d4nilo, tenh4 um4 bo4 noite!
# @fredgol9 pho fredao faz 4 rodada que te escal9 no cartola vamo te que bomba na proxima ahahhaha
# @fredgol9 Aguardando já esse LIXO do @fredgol9 afundar o Cruzeiro.
# Vem tranquilo @fredgol9 🇮🇹 https://t.co/VkQ3v2q5KW
# RT @CruzeiroVerdad2: @fredgol9 Pega sua malinha e seu celular e vai fazer stories em outro lugar. https://t.co/S6rcQH8reX
# @fredgol9 Confio no seu futebol,guerreiro!
# @fredgol9 Volta capitão!
# Perder para o FLUMINENcE já uma merda, de goleada pior ainda @Cruzeiro  perder para um time minúsculo desse vergonhoso @fredgol9 some!
# @thiagofredgol @bernardofrancas @leopancierii @fredgol9 Vou nem zoar o advogado vai que ele me processa
# @bernardofrancas @Danilo65049691 @leopancierii @fredgol9 fic4 put4 n4o, c4chorrinh4
# @chcruzerao @fredgol9 Se continuar assim vai ser difícil, mas esperança é a última que morre
# @fredgol9 Moio
# @fredgol9 O cone que não faz gol
# VOLTA LOGO PORRA @fredgol9
# @fredgol9 fica aí no Rio
# RT @CruzeiroVerdad2: @fredgol9 Pega sua malinha e seu celular e vai fazer stories em outro lugar. https://t.co/S6rcQH8reX
# Sou mais radical, está bom da diretoria repensar se @manomenezes  e a melhor escolha pro @Cruzeiro hj , não tem variações de jogada e vejo muito contido com o elenco , e tem uns jogadores lá q já deu né , um atacante q não chuta uma bola no gol ajuda nos aí @fredgol9 , mano
# @CruzeiroVerdad2 @fredgol9 AtleticoVerdade vc devia chamar. Desculpe.
# @fredgol9 Pô pede desculpa pro Matheus Ferraz por ter entrado no bolso dele sem pedir
# @fredgol9 aí Fred tá tirando né?, mermão te pedi na copa América até mandei mensagem pro tite,e tu rateia cmg no Cartola daí não dá mané ksksksk
# @wander_a_cruz @fredgol9 @FluminenseFC Obrigado por sempre se arrastar em campo contra o Flu. Volta Dom
# @IaanDRN @fredgol9 O jeito é torcer pra que o Cruzeiro vingue nas copas de novo né
# @fredgol9 Vai toma no seu cu, filho da puta. Mercenário. Arrogante do caralho. Vai puta que te pariu.
# @fredgol9 Pipoca.
# @chcruzerao @fredgol9 Fato, realmente prejudicou mas o time não pode depender de 1 lance o cruzeiro tem um elenco de dar inveja
# @fredgol9 Cone de merda. Som do Cruzeiro, seu bosta!!!
# @Danilo65049691 @bernardofrancas @leopancierii @fredgol9 t4mo junto, obrig4do
# @fredgol9 Eu não vou tocar pra você se você estiver com dó - LIMA, Henrique.
# @fredgol9 Joga mais bola hein!
# @fredgol9 Pega sua malinha e seu celular e vai fazer stories em outro lugar. https://t.co/S6rcQH8reX
# Obrigado, @fredgol9! Mais uma vez fidalgo com o FLUZÃO 🇭🇺
# @thiagofredgol @bernardofrancas @leopancierii @fredgol9 Tô calmo série C
# @fredgol9 Volta pro fluminense filho da puta! Dois jogos que vc nem na bola foi
# @fredgol9 Tava com dó, fdp....??? @fredgol9
# @diogofaria83 @fredgol9 Criuze?
# RT @fredgol9: 🙏🏼🦊🔵 https://t.co/Urhv55aHca
# @IaanDRN @fredgol9 Né kkkkkk
# Mas cara, na moral mesmo. Nós Cruzeirenses não somos de chorar arbitragem, e sim o desempenho dos jogadores, mas se tivesse dado aquela falta e cartão vermelho nos 2 minutos de jogo, muda tudo.. mas enfim, o Cruzeiro não tá merecendo nem está reclamação 6/45
# RT @gustavonolascoB: A diferença do que o @fredgol9 fez nesses dois jogos contra o Flumimense e o que o Edmundo fez ao errar o pênalti cont…
# @Danilo65049691 @bernardofrancas @leopancierii @fredgol9 c4lm4, por f4vor
# Achei que o @fredgol9 ia dar show no jogo hj. A rodada mal começou e eu já me fodi no cartola
# RT @gustavonolascoB: A diferença do que o @fredgol9 fez nesses dois jogos contra o Flumimense e o que o Edmundo fez ao errar o pênalti cont…
# RT @fredgol9: 🙏🏼🦊🔵 https://t.co/Urhv55aHca
# Eu quero que o @fredgol9 vai pra Puta que o Pariu!!!
# Ou seja, para o @FluminenseFC
# @danielnatu @fredgol9 @samuelvenancio @Cruzeiro_News @Cruzeiro
# @fredgol9 Vai toma no cu
# RT @IgorRock92: @Cachazeiros @fredgol9 Time ta inoperante. Jogando absolutamente NADA. Nao consigo entender como pode haver queda tao abrup…
# @fredgol9 Ídolo! Estamos lhe aguardando de volta!
# Dom da uma moral, manda um abraço para meus filhos Pedro e Bernardo, os mulekes são mais Fred FC do que FLU FC...
# Muita saúde sempre!
# @chcruzerao @fredgol9 Aí é a hora que você pensa:
#
# Se o PR tivesse tocado pro Fred e ele feito o gol você teria:
#
# Provavelmente comemorado a vitória do Cruzeiro
# Eu de saia na praça 6
# Não sei quem me ilude mais, se é a mina da quebrada ou um tal de  és @fredgol9 @cartolafc https://t.co/mfz2m2POB2
# @thiagofredgol @bernardofrancas @leopancierii @fredgol9 Vou ficar triste aqui perto das minha 6 copa do Brasil o série C
# Vou falar oq vi aqui no maraca desses dois jogos... nunca vi um jogador tão apático igual ao @fredgol9 vtnc
# @Danilo65049691 @bernardofrancas @leopancierii @fredgol9 fic4 triste n4o
# @IaanDRN @fredgol9 Se pelo menos o Fred tivesse feito gol, iria me divertir, mesmo com a derrota.. fase tá ruim kkkkk https://t.co/PU5PZYKXFr
# @fredgol9 Tá de sacanagem Ja!!!!!
# @fredgol9 Volta
# @fredgol9 Eu não disse? #FredÍdoloTricolor #Fred
# @pedrujopassos @ibismania @fredgol9 Tá deixando de jogar pra ser vendido.
# @chcruzerao @fredgol9 Nossa ainda bem ksjsksjs
# @Cachazeiros @Thiago_bigode_ @fredgol9 Fora mano
# @thiagofredgol @bernardofrancas @leopancierii @fredgol9 Os advogados vem aí é muita taça eu vou ganhar
# @Cachazeiros @Thiago_bigode_ @fredgol9 AHAHHAHAHAHAHAHAHHAHAHA
# @thiagofredgol @constantiniluis @bernardofrancas @leopancierii @fredgol9 Valeu pelo oq noiado? Para a série B que vcs devem vc n quer não ne
# @Nardo174 @fredgol9 esse é o n4ndo l4 b4rc4
# RT @Cachazeiros: Mais de 180 minutos e 50 finalizações do Fluminense contra 4 do Cruzeiro, que porra é essa? @fredgol9 nunca ganhou contra…
# @gabriel_s71 @fredgol9 Kkkkkkkkkkkkkk
# Esse @fredgol9 é o maior MARKETEIRO da história do futebol brasileiro, ator...por isso é o rei dos stories
# Exxxx jogador tem pelo menos 5 anos
# Morre com ele MANO...logo vc hein Mano? Futebol por debaixo dos panos prega peças! Vai saber...
# @samuelvenancio
# @fredgol9 😂🤣😂🤣😂🤣😂🤣😂🤣😂🤣😂🤣😂🤣
# @bernardofrancas @Danilo65049691 @leopancierii @fredgol9 v4leu m4ri4
# @Danilo65049691 @constantiniluis @bernardofrancas @leopancierii @fredgol9 v4leu m4ri4!
# @MM9oficial Simples... Mas a diretoria tem que ter peito e tirar o cara agora. Pedir pra sair ele não vai.... E por sinal, pode voltar guerreiro porque sua perna se estiver amarrada joga mais que a do @fredgol9 que só faz gol em mineiro...
# @anacl_aras @fredgol9 acovardou!
# @IaanDRN @fredgol9 Vc tem que usar a mesma visão que teve só Fred pro cartola, amigo! Você tem potencial! Já tinha até tirado o print pra cobrar 😂😂😂😂 iludido sou eu https://t.co/CZb9bdz0XS
# @fredgol9 te amo, fredão!
# @Fluminensee1902 @_kauaffc10 @fredgol9 Eu pensei que o ganso e o Fred iam sair na porrada no segundo tempo
# @fredgol9 Lixooooooo. Nunca será ídolo em lugar algum. Espero que o cruzeiro atrapalhe sua carreira colo vc está atrapalhando o cruzeiro.
# @fredgol9 Tá rolando alguma treta interna.... Dá um jeito com os companheiros pq time tem, salário parece estar em dia, e vcs não estão jogando porra nenhuma, só querem mídia, vamo jogar bola....
# @antony_santos12 @N5Eoficial @fredgol9 Acho o Rodriguinho.
# Fora Mano Menezes, toma no cu, time jogando igual o time de várzea aqui da cidade, se fuder, tirando o pé. @fredgol9 com dó do fluminense nem dominar uma bola consegue.
# @ibismania @fredgol9  olha o que voltou a ser ! Vai jogar bola ?
# @fredgol9 Poxa…4x1 né deu ruim kkkk
# @fredgol9 vc não joga contra o Fluminense hein sujeito..
# E agora @Dedevital @fabiogoleiro_01 @lucas_romero29 @16LucasSilva @fredgol9 tomar 4 do fluminense? Vcs não tem vergonha? Decepcionante o que vcs vem apresentando a 7 jogos. Vergonhoso o que andam apresentando. Vamos jogar com vontade porra. Tnc
# @fredgol9 Tmj irmão Vms apoiar , time vai reverter isso !
# @fredgol9 Mortoooooooo
# @fredgol9 volta pro lugar, que sempre foi seu
# Ta vendo @fredgol9 seu lugar é no @FluminenseFC. Vem voltar a ser artilheiro goleador. #4x1
# @fredgol9 😫😫😫😫
# RT @Cachazeiros: Mais de 180 minutos e 50 finalizações do Fluminense contra 4 do Cruzeiro, que porra é essa? @fredgol9 nunca ganhou contra…
# @fredgol9 #forafred desgraçado
# @SporTV Então volta pra lá @fredgol9 ! Vc deveria está falando o qto vcs estão jogando mal, não parabenizando quem meteu goleada em nos
# @fredgol9 Não sei c e o estilo de jogo do retranqueiro Mano ou e vc que tá MUITO mal mesmo, para de ir pra nossa área defender caralho vc não e zagueiro

# %%
fred_tweets = [obj._json for obj in api.search(q="@fredgol9", count=1000, tweet_mode="extended", since='2018-01-01')]

# %%
jp_tweets = [obj._json for obj in api.search(q="joão pedro fluminense", count=1000, tweet_mode="extended", since='2018-01-01')]

# %%
jp_tweets
# Out:
# [{'created_at': 'Mon May 27 14:33:59 +0000 2019',
#   'id': 1133018515328380934,
#   'id_str': '1133018515328380934',
#   'full_text': 'RT @betosalesrio: João Pedro é o maior ídolo da história do Fluminense nos últimos dez dias.',
#   'truncated': False,
#   'display_text_range': [0, 92],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'betosalesrio',
#      'name': 'Beto Sales',
#      'id': 53652311,
#      'id_str': '53652311',
#      'indices': [3, 16]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 915686921355096064,
#    'id_str': '915686921355096064',
#    'name': 'Igor',
#    'screen_name': 'Igorkkkkk',
#    'location': '',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 75,
#    'friends_count': 323,
#    'listed_count': 0,
#    'created_at': 'Wed Oct 04 21:15:49 +0000 2017',
#    'favourites_count': 27647,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 5082,
#    'lang': 'pt',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1020429870873174016/dxnj6wPh_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1020429870873174016/dxnj6wPh_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/915686921355096064/1520364301',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Fri May 24 02:07:12 +0000 2019',
#    'id': 1131743416994410496,
#    'id_str': '1131743416994410496',
#    'full_text': 'João Pedro é o maior ídolo da história do Fluminense nos últimos dez dias.',
#    'truncated': False,
#    'display_text_range': [0, 74],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 53652311,
#     'id_str': '53652311',
#     'name': 'Beto Sales',
#     'screen_name': 'betosalesrio',
#     'location': 'Rio de Janeiro',
#     'description': 'Ninguém tem razão',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 3348,
#     'friends_count': 437,
#     'listed_count': 52,
#     'created_at': 'Sat Jul 04 11:41:33 +0000 2009',
#     'favourites_count': 23042,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': False,
#     'statuses_count': 26906,
#     'lang': 'pt',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '070000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1037718811661746178/_MsmM_jl_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1037718811661746178/_MsmM_jl_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/53652311/1473879986',
#     'profile_link_color': '1C1C1C',
#     'profile_sidebar_border_color': 'C1C2C0',
#     'profile_sidebar_fill_color': 'FCFCFC',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 197,
#    'favorite_count': 857,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'pt'},
#   'is_quote_status': False,
#   'retweet_count': 197,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'pt'},
#  {'created_at': 'Mon May 27 14:32:19 +0000 2019',
#   'id': 1133018097957445632,
#   'id_str': '1133018097957445632',
#   'full_text': 'João Pedro: joia, tem um futuro espetacular, tem números impressionantes, tem tudo pra deslanchar, Fluminense precisa dar um jeito de segurar esse mlk por mais um tempo, joga muita bola',
#   'truncated': False,
#   'display_text_range': [0, 185],
#   'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [], 'urls': []},
#   'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1132838668413091841,
#    'id_str': '1132838668413091841',
#    'name': 'FLUZÃO DEPRÊ SC',
#    'screen_name': 'FluzaoS',
#    'location': '',
#    'description': 'Tricolor carioca since 1999 | Conta criada para glorificar, enaltecer, exaltar e engrandecer o zagueiro Maldini das Laranjeiras',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 2,
#    'friends_count': 67,
#    'listed_count': 0,
#    'created_at': 'Mon May 27 02:39:20 +0000 2019',
#    'favourites_count': 41,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 58,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1132840612670128132/OZoTRHUy_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1132840612670128132/OZoTRHUy_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1132838668413091841/1558925224',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'pt'},
#  {'created_at': 'Mon May 27 14:29:07 +0000 2019',
#   'id': 1133017292051292162,
#   'id_str': '1133017292051292162',
#   'full_text': 'RT @FTalentScout: 17-year-old Fluminense forward João Pedro last four games for Fluminense:\n\n6 minutes vs Cruzeiro ⚽️\n20 minutes vs Cruzeir…',
#   'truncated': False,
#   'display_text_range': [0, 140],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'FTalentScout',
#      'name': 'FootballTalentScout',
#      'id': 2266207230,
#      'id_str': '2266207230',
#      'indices': [3, 16]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 958006681182629888,
#    'id_str': '958006681182629888',
#    'name': 'Josh',
#    'screen_name': 'WatfordAddict',
#    'location': 'Watford, England',
#    'description': '@watfordfc @joshwalkdenn',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 192,
#    'friends_count': 304,
#    'listed_count': 0,
#    'created_at': 'Mon Jan 29 15:59:26 +0000 2018',
#    'favourites_count': 5219,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 1267,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1091395013093875717/6jCqiAC-_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1091395013093875717/6jCqiAC-_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/958006681182629888/1544536834',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Mon May 27 03:33:55 +0000 2019',
#    'id': 1132852407069761536,
#    'id_str': '1132852407069761536',
#    'full_text': '17-year-old Fluminense forward João Pedro last four games for Fluminense:\n\n6 minutes vs Cruzeiro ⚽️\n20 minutes vs Cruzeiro ⚽️⚽️\n90 minutes vs Atlético Nacional ⚽️⚽️⚽️🅰️\n90 minutes vs Bahia ⚽️\n\nUnstoppable! 🔥🇧🇷',
#    'truncated': False,
#    'display_text_range': [0, 209],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2266207230,
#     'id_str': '2266207230',
#     'name': 'FootballTalentScout',
#     'screen_name': 'FTalentScout',
#     'location': '',
#     'description': 'Probably the best website about football talents in the world.',
#     'url': 'http://t.co/SeRNGT2bnj',
#     'entities': {'url': {'urls': [{'url': 'http://t.co/SeRNGT2bnj',
#         'expanded_url': 'http://footballtalentscout.net/',
#         'display_url': 'footballtalentscout.net',
#         'indices': [0, 22]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 74312,
#     'friends_count': 461,
#     'listed_count': 490,
#     'created_at': 'Sat Dec 28 17:34:24 +0000 2013',
#     'favourites_count': 3936,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 257,
#     'lang': 'en-gb',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/862674217199968258/QB1O6dJA_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/862674217199968258/QB1O6dJA_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2266207230/1494263791',
#     'profile_link_color': 'ABB8C2',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 45,
#    'favorite_count': 426,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'pt'},
#   'is_quote_status': False,
#   'retweet_count': 45,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'pt'},
#  {'created_at': 'Mon May 27 14:15:48 +0000 2019',
#   'id': 1133013940118728704,
#   'id_str': '1133013940118728704',
#   'full_text': 'RT @FTalentScout: 17-year-old Fluminense forward João Pedro last four games for Fluminense:\n\n6 minutes vs Cruzeiro ⚽️\n20 minutes vs Cruzeir…',
#   'truncated': False,
#   'display_text_range': [0, 140],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'FTalentScout',
#      'name': 'FootballTalentScout',
#      'id': 2266207230,
#      'id_str': '2266207230',
#      'indices': [3, 16]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1020326781952372736,
#    'id_str': '1020326781952372736',
#    'name': 'Sam Witherspoon',
#    'screen_name': 'samwitherspoon1',
#    'location': 'Aylesbury, England',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 40,
#    'friends_count': 204,
#    'listed_count': 1,
#    'created_at': 'Fri Jul 20 15:17:16 +0000 2018',
#    'favourites_count': 11988,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 1922,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1076622442754465797/2zlsS_iM_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1076622442754465797/2zlsS_iM_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1020326781952372736/1532110499',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Mon May 27 03:33:55 +0000 2019',
#    'id': 1132852407069761536,
#    'id_str': '1132852407069761536',
#    'full_text': '17-year-old Fluminense forward João Pedro last four games for Fluminense:\n\n6 minutes vs Cruzeiro ⚽️\n20 minutes vs Cruzeiro ⚽️⚽️\n90 minutes vs Atlético Nacional ⚽️⚽️⚽️🅰️\n90 minutes vs Bahia ⚽️\n\nUnstoppable! 🔥🇧🇷',
#    'truncated': False,
#    'display_text_range': [0, 209],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2266207230,
#     'id_str': '2266207230',
#     'name': 'FootballTalentScout',
#     'screen_name': 'FTalentScout',
#     'location': '',
#     'description': 'Probably the best website about football talents in the world.',
#     'url': 'http://t.co/SeRNGT2bnj',
#     'entities': {'url': {'urls': [{'url': 'http://t.co/SeRNGT2bnj',
#         'expanded_url': 'http://footballtalentscout.net/',
#         'display_url': 'footballtalentscout.net',
#         'indices': [0, 22]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 74312,
#     'friends_count': 461,
#     'listed_count': 490,
#     'created_at': 'Sat Dec 28 17:34:24 +0000 2013',
#     'favourites_count': 3936,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 257,
#     'lang': 'en-gb',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/862674217199968258/QB1O6dJA_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/862674217199968258/QB1O6dJA_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2266207230/1494263791',
#     'profile_link_color': 'ABB8C2',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 45,
#    'favorite_count': 426,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'pt'},
#   'is_quote_status': False,
#   'retweet_count': 45,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'pt'},
#  {'created_at': 'Mon May 27 14:13:02 +0000 2019',
#   'id': 1133013246099767298,
#   'id_str': '1133013246099767298',
#   'full_text': 'RT @FTalentScout: 17-year-old Fluminense forward João Pedro last four games for Fluminense:\n\n6 minutes vs Cruzeiro ⚽️\n20 minutes vs Cruzeir…',
#   'truncated': False,
#   'display_text_range': [0, 140],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'FTalentScout',
#      'name': 'FootballTalentScout',
#      'id': 2266207230,
#      'id_str': '2266207230',
#      'indices': [3, 16]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 746734144714080256,
#    'id_str': '746734144714080256',
#    'name': 'Aaron',
#    'screen_name': 'aaron_bennis10',
#    'location': 'Borehamwood',
#    'description': '17 ~ Graphic Designer for @WD18fans and @the_1881_club, Watford FC Home and Away Regular',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 519,
#    'friends_count': 571,
#    'listed_count': 1,
#    'created_at': 'Sat Jun 25 15:57:48 +0000 2016',
#    'favourites_count': 58664,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 21451,
#    'lang': 'en-GB',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '000000',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1010519262044278784/tnLnfVxp_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1010519262044278784/tnLnfVxp_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/746734144714080256/1555966342',
#    'profile_link_color': 'FAB81E',
#    'profile_sidebar_border_color': '000000',
#    'profile_sidebar_fill_color': '000000',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Mon May 27 03:33:55 +0000 2019',
#    'id': 1132852407069761536,
#    'id_str': '1132852407069761536',
#    'full_text': '17-year-old Fluminense forward João Pedro last four games for Fluminense:\n\n6 minutes vs Cruzeiro ⚽️\n20 minutes vs Cruzeiro ⚽️⚽️\n90 minutes vs Atlético Nacional ⚽️⚽️⚽️🅰️\n90 minutes vs Bahia ⚽️\n\nUnstoppable! 🔥🇧🇷',
#    'truncated': False,
#    'display_text_range': [0, 209],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2266207230,
#     'id_str': '2266207230',
#     'name': 'FootballTalentScout',
#     'screen_name': 'FTalentScout',
#     'location': '',
#     'description': 'Probably the best website about football talents in the world.',
#     'url': 'http://t.co/SeRNGT2bnj',
#     'entities': {'url': {'urls': [{'url': 'http://t.co/SeRNGT2bnj',
#         'expanded_url': 'http://footballtalentscout.net/',
#         'display_url': 'footballtalentscout.net',
#         'indices': [0, 22]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 74312,
#     'friends_count': 461,
#     'listed_count': 490,
#     'created_at': 'Sat Dec 28 17:34:24 +0000 2013',
#     'favourites_count': 3936,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 257,
#     'lang': 'en-gb',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/862674217199968258/QB1O6dJA_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/862674217199968258/QB1O6dJA_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2266207230/1494263791',
#     'profile_link_color': 'ABB8C2',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 45,
#    'favorite_count': 426,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'pt'},
#   'is_quote_status': False,
#   'retweet_count': 45,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'pt'},
#  {'created_at': 'Mon May 27 14:07:48 +0000 2019',
#   'id': 1133011929348366336,
#   'id_str': '1133011929348366336',
#   'full_text': '@antony00 @SaoPauloFC @puma_br Assiste o João Pedro do fluminense vê se aprende com ele dedicação. Moleque guardando vários gol e dando assistência..',
#   'truncated': False,
#   'display_text_range': [31, 149],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'antony00',
#      'name': 'Antony Santos',
#      'id': 917812374782070785,
#      'id_str': '917812374782070785',
#      'indices': [0, 9]},
#     {'screen_name': 'SaoPauloFC',
#      'name': 'São Paulo FC',
#      'id': 24920669,
#      'id_str': '24920669',
#      'indices': [10, 21]},
#     {'screen_name': 'puma_br',
#      'name': 'PUMA Brasil',
#      'id': 281551749,
#      'id_str': '281551749',
#      'indices': [22, 30]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': 1132737368144920577,
#   'in_reply_to_status_id_str': '1132737368144920577',
#   'in_reply_to_user_id': 917812374782070785,
#   'in_reply_to_user_id_str': '917812374782070785',
#   'in_reply_to_screen_name': 'antony00',
#   'user': {'id': 1083453366695612423,
#    'id_str': '1083453366695612423',
#    'name': 'Matias',
#    'screen_name': 'Matias__Batista',
#    'location': '',
#    'description': 'Deus',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 7,
#    'friends_count': 65,
#    'listed_count': 0,
#    'created_at': 'Thu Jan 10 19:59:47 +0000 2019',
#    'favourites_count': 483,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 186,
#    'lang': 'pt',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1097841391844118530/vzM7HvpI_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1097841391844118530/vzM7HvpI_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1083453366695612423/1547150564',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'pt'},
#  {'created_at': 'Mon May 27 13:49:38 +0000 2019',
#   'id': 1133007354595872770,
#   'id_str': '1133007354595872770',
#   'full_text': 'RT @FTalentScout: 17-year-old Fluminense forward João Pedro last four games for Fluminense:\n\n6 minutes vs Cruzeiro ⚽️\n20 minutes vs Cruzeir…',
#   'truncated': False,
#   'display_text_range': [0, 140],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'FTalentScout',
#      'name': 'FootballTalentScout',
#      'id': 2266207230,
#      'id_str': '2266207230',
#      'indices': [3, 16]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 849778711041900544,
#    'id_str': '849778711041900544',
#    'name': 'Henrique Melo 🇵🇹',
#    'screen_name': 'azoreanthief69',
#    'location': 'Nordeste, Portugal',
#    'description': 'FC Porto 💙🐲 Manchester United 👹 LA Lakers 💙\U0001f9e1',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 74,
#    'friends_count': 322,
#    'listed_count': 0,
#    'created_at': 'Thu Apr 06 00:20:07 +0000 2017',
#    'favourites_count': 4441,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 2429,
#    'lang': 'pt',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1132999295848931328/L0nz-5Sn_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1132999295848931328/L0nz-5Sn_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/849778711041900544/1551917068',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Mon May 27 03:33:55 +0000 2019',
#    'id': 1132852407069761536,
#    'id_str': '1132852407069761536',
#    'full_text': '17-year-old Fluminense forward João Pedro last four games for Fluminense:\n\n6 minutes vs Cruzeiro ⚽️\n20 minutes vs Cruzeiro ⚽️⚽️\n90 minutes vs Atlético Nacional ⚽️⚽️⚽️🅰️\n90 minutes vs Bahia ⚽️\n\nUnstoppable! 🔥🇧🇷',
#    'truncated': False,
#    'display_text_range': [0, 209],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2266207230,
#     'id_str': '2266207230',
#     'name': 'FootballTalentScout',
#     'screen_name': 'FTalentScout',
#     'location': '',
#     'description': 'Probably the best website about football talents in the world.',
#     'url': 'http://t.co/SeRNGT2bnj',
#     'entities': {'url': {'urls': [{'url': 'http://t.co/SeRNGT2bnj',
#         'expanded_url': 'http://footballtalentscout.net/',
#         'display_url': 'footballtalentscout.net',
#         'indices': [0, 22]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 74312,
#     'friends_count': 461,
#     'listed_count': 490,
#     'created_at': 'Sat Dec 28 17:34:24 +0000 2013',
#     'favourites_count': 3936,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 257,
#     'lang': 'en-gb',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/862674217199968258/QB1O6dJA_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/862674217199968258/QB1O6dJA_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2266207230/1494263791',
#     'profile_link_color': 'ABB8C2',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 45,
#    'favorite_count': 426,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'pt'},
#   'is_quote_status': False,
#   'retweet_count': 45,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'pt'},
#  {'created_at': 'Mon May 27 13:48:28 +0000 2019',
#   'id': 1133007063771176968,
#   'id_str': '1133007063771176968',
#   'full_text': 'RT @FTalentScout: 17-year-old Fluminense forward João Pedro last four games for Fluminense:\n\n6 minutes vs Cruzeiro ⚽️\n20 minutes vs Cruzeir…',
#   'truncated': False,
#   'display_text_range': [0, 140],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'FTalentScout',
#      'name': 'FootballTalentScout',
#      'id': 2266207230,
#      'id_str': '2266207230',
#      'indices': [3, 16]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 957316646066061312,
#    'id_str': '957316646066061312',
#    'name': 'dean',
#    'screen_name': 'WFC_Dean',
#    'location': '',
#    'description': '• Watford FC 🐝 • NYG 🏈',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1090,
#    'friends_count': 852,
#    'listed_count': 1,
#    'created_at': 'Sat Jan 27 18:17:29 +0000 2018',
#    'favourites_count': 9424,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 4403,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1132996337073573888/LlH6sO-h_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1132996337073573888/LlH6sO-h_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/957316646066061312/1558962353',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Mon May 27 03:33:55 +0000 2019',
#    'id': 1132852407069761536,
#    'id_str': '1132852407069761536',
#    'full_text': '17-year-old Fluminense forward João Pedro last four games for Fluminense:\n\n6 minutes vs Cruzeiro ⚽️\n20 minutes vs Cruzeiro ⚽️⚽️\n90 minutes vs Atlético Nacional ⚽️⚽️⚽️🅰️\n90 minutes vs Bahia ⚽️\n\nUnstoppable! 🔥🇧🇷',
#    'truncated': False,
#    'display_text_range': [0, 209],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': []},
#    'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2266207230,
#     'id_str': '2266207230',
#     'name': 'FootballTalentScout',
#     'screen_name': 'FTalentScout',
#     'location': '',
#     'description': 'Probably the best website about football talents in the world.',
#     'url': 'http://t.co/SeRNGT2bnj',
#     'entities': {'url': {'urls': [{'url': 'http://t.co/SeRNGT2bnj',
#         'expanded_url': 'http://footballtalentscout.net/',
#         'display_url': 'footballtalentscout.net',
#         'indices': [0, 22]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 74312,
#     'friends_count': 461,
#     'listed_count': 490,
#     'created_at': 'Sat Dec 28 17:34:24 +0000 2013',
#     'favourites_count': 3936,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 257,
#     'lang': 'en-gb',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/862674217199968258/QB1O6dJA_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/862674217199968258/QB1O6dJA_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2266207230/1494263791',
#     'profile_link_color': 'ABB8C2',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 45,
#    'favorite_count': 426,
#    'favorited': False,
#    'retweeted': False,
#    'lang': 'pt'},
#   'is_quote_status': False,
#   'retweet_count': 45,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'pt'},
#  {'created_at': 'Mon May 27 13:41:57 +0000 2019',
#   'id': 1133005423332737024,
#   'id_str': '1133005423332737024',
#   'full_text': 'RT @AnfieldHQ: Fluminense have already agreed a deal with Watford for 17-year-old Joao Pedro, but Liverpool could reportedly throw a £20mil…',
#   'truncated': False,
#   'display_text_range': [0, 140],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'AnfieldHQ',
#      'name': 'Anfield HQ',
#      'id': 2525206496,
#      'id_str': '2525206496',
#      'indices': [3, 13]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 229479359,
#    'id_str': '229479359',
#    'name': 'Carlos Junior',
#    'screen_name': 'Fluzao2019',
#    'location': '',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 435,
#    'friends_count': 791,
#    'listed_count': 4,
#    'created_at': 'Wed Dec 22 14:17:08 +0000 2010',
#    'favourites_count': 1261,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 11679,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1090986199051878401/9_Yw1wMh_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1090986199051878401/9_Yw1wMh_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/229479359/1400176010',
#    'profile_link_color': '0084B4',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Mon May 27 10:12:00 +0000 2019',
#    'id': 1132952585776902145,
#    'id_str': '1132952585776902145',
#    'full_text': 'Fluminense have already agreed a deal with Watford for 17-year-old Joao Pedro, but Liverpool could reportedly throw a £20million spanner in the works.\n\nhttps://t.co/zGmugCtO5A',
#    'truncated': False,
#    'display_text_range': [0, 175],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [{'url': 'https://t.co/zGmugCtO5A',
#       'expanded_url': 'https://www.anfieldhq.com/reds-could-hijack-watford-deal-for-brazilian-forward-joao-pedro/',
#       'display_url': 'anfieldhq.com/reds-could-hij…',
#       'indices': [152, 175]}]},
#    'metadata': {'iso_language_code': 'en', 'result_type': 'recent'},
#    'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 2525206496,
#     'id_str': '2525206496',
#     'name': 'Anfield HQ',
#     'screen_name': 'AnfieldHQ',
#     'location': 'United Kingdom',
#     'description': '🖥 Independent @LFC Site 📰Daily News and Analysis🏆 Multi-Award Winning at @TheFBAS📱Online Since 2014 ➡️ https://t.co/TkWqwyhdfY',
#     'url': 'https://t.co/JCBccg1q2a',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/JCBccg1q2a',
#         'expanded_url': 'http://www.anfieldhq.com',
#         'display_url': 'anfieldhq.com',
#         'indices': [0, 23]}]},
#      'description': {'urls': [{'url': 'https://t.co/TkWqwyhdfY',
#         'expanded_url': 'https://www.anfieldhq.com/contact-us/',
#         'display_url': 'anfieldhq.com/contact-us/',
#         'indices': [103, 126]}]}},
#     'protected': False,
#     'followers_count': 275814,
#     'friends_count': 1037,
#     'listed_count': 1627,
#     'created_at': 'Mon May 26 14:57:04 +0000 2014',
#     'favourites_count': 20373,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 124138,
#     'lang': 'en-gb',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'C0DEED',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1006865741751218176/WjYVR3Bk_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1006865741751218176/WjYVR3Bk_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2525206496/1557268887',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': False,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 8,
#    'favorite_count': 77,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'en'},
#   'is_quote_status': False,
#   'retweet_count': 8,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'en'},
#  {'created_at': 'Mon May 27 13:41:33 +0000 2019',
#   'id': 1133005321042108416,
#   'id_str': '1133005321042108416',
#   'full_text': 'RT @sport: #Fútbol 🇧🇷 | Joao Pedro: ha nacido una estrella https://t.co/ZS7jXD5yQ7 \n\n⭐ Delantero del Fluminense de 17 años \n⚽ 8 goles en 9…',
#   'truncated': False,
#   'display_text_range': [0, 139],
#   'entities': {'hashtags': [{'text': 'Fútbol', 'indices': [11, 18]}],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'sport',
#      'name': 'Diario SPORT',
#      'id': 19343904,
#      'id_str': '19343904',
#      'indices': [3, 9]}],
#    'urls': [{'url': 'https://t.co/ZS7jXD5yQ7',
#      'expanded_url': 'http://bit.ly/2JMLN9d',
#      'display_url': 'bit.ly/2JMLN9d',
#      'indices': [59, 82]}]},
#   'metadata': {'iso_language_code': 'es', 'result_type': 'recent'},
#   'source': '<a href="https://mobile.twitter.com" rel="nofollow">Twitter Web App</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 229479359,
#    'id_str': '229479359',
#    'name': 'Carlos Junior',
#    'screen_name': 'Fluzao2019',
#    'location': '',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 435,
#    'friends_count': 791,
#    'listed_count': 4,
#    'created_at': 'Wed Dec 22 14:17:08 +0000 2010',
#    'favourites_count': 1261,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 11679,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1090986199051878401/9_Yw1wMh_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1090986199051878401/9_Yw1wMh_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/229479359/1400176010',
#    'profile_link_color': '0084B4',
# ...
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1556325758,
#    'id_str': '1556325758',
#    'name': 'Flu Maior',
#    'screen_name': 'FLUMAIOR',
#    'location': 'Jamaica ( Iowa ).',
#    'description': 'Tricolor doente e brasileiro decente, papo reto...ST.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 3634,
#    'friends_count': 4066,
#    'listed_count': 13,
#    'created_at': 'Sat Jun 29 19:00:08 +0000 2013',
#    'favourites_count': 10026,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 23276,
#    'lang': 'pt',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '0A2E02',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1034433174691082240/H6qVlX-J_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1034433174691082240/H6qVlX-J_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1556325758/1518301755',
#    'profile_link_color': '06B300',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'pt'},
#  {'created_at': 'Mon May 27 06:59:48 +0000 2019',
#   'id': 1132904216945729537,
#   'id_str': '1132904216945729537',
#   'full_text': 'RT @CentralFoxBR: 🇮🇹 EMOCIONANTE! Fã do rapper Xamã, João Pedro vive boa fase no Fluminense e se emociona ao falar da família! #CentralFOXB…',
#   'truncated': False,
#   'display_text_range': [0, 140],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'CentralFoxBR',
#      'name': 'Central FOX Brasil',
#      'id': 3097539491,
#      'id_str': '3097539491',
#      'indices': [3, 16]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 758699464513228801,
#    'id_str': '758699464513228801',
#    'name': 'shamyra.',
#    'screen_name': 'shamyra99',
#    'location': 'vou te levar p um lugar lindo',
#    'description': '1994•24/10/16•04/03•21/03/19  23:45• flamengo ❤️🖤',
#    'url': 'https://t.co/abKdrKIyXO',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/abKdrKIyXO',
#        'expanded_url': 'https://curiouscat.me/shamyra99',
#        'display_url': 'curiouscat.me/shamyra99',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 655,
#    'friends_count': 779,
#    'listed_count': 0,
#    'created_at': 'Thu Jul 28 16:23:43 +0000 2016',
#    'favourites_count': 19507,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 23656,
#    'lang': 'pt',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1130315319078203392/KEH9jjZD_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1130315319078203392/KEH9jjZD_normal.jpg',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Tue May 21 02:46:58 +0000 2019',
#    'id': 1130666264282767361,
#    'id_str': '1130666264282767361',
#    'full_text': '🇮🇹 EMOCIONANTE! Fã do rapper Xamã, João Pedro vive boa fase no Fluminense e se emociona ao falar da família! #CentralFOXBR https://t.co/Ffd5GKngKn',
#    'truncated': False,
#    'display_text_range': [0, 122],
#    'entities': {'hashtags': [{'text': 'CentralFOXBR', 'indices': [109, 122]}],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [],
#     'media': [{'id': 1130665764460093440,
#       'id_str': '1130665764460093440',
#       'indices': [123, 146],
#       'media_url': 'http://pbs.twimg.com/media/D7DunINXsAEmys0.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/D7DunINXsAEmys0.jpg',
#       'url': 'https://t.co/Ffd5GKngKn',
#       'display_url': 'pic.twitter.com/Ffd5GKngKn',
#       'expanded_url': 'https://twitter.com/CentralFoxBR/status/1130666264282767361/video/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 1920, 'h': 1080, 'resize': 'fit'},
#        'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 383, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1130665764460093440,
#       'id_str': '1130665764460093440',
#       'indices': [123, 146],
#       'media_url': 'http://pbs.twimg.com/media/D7DunINXsAEmys0.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/D7DunINXsAEmys0.jpg',
#       'url': 'https://t.co/Ffd5GKngKn',
#       'display_url': 'pic.twitter.com/Ffd5GKngKn',
#       'expanded_url': 'https://twitter.com/CentralFoxBR/status/1130666264282767361/video/1',
#       'type': 'video',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 1920, 'h': 1080, 'resize': 'fit'},
#        'medium': {'w': 1200, 'h': 675, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 383, 'resize': 'fit'}},
#       'video_info': {'aspect_ratio': [16, 9],
#        'duration_millis': 276134,
#        'variants': [{'content_type': 'application/x-mpegURL',
#          'url': 'https://video.twimg.com/amplify_video/1130665764460093440/pl/eSC_am05CEtvjCJn.m3u8?tag=12'},
#         {'bitrate': 288000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/amplify_video/1130665764460093440/vid/320x180/1cAMcRGFj9UrrURo.mp4?tag=12'},
#         {'bitrate': 2176000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/amplify_video/1130665764460093440/vid/1280x720/NAYdrVmKPcj2lKN5.mp4?tag=12'},
#         {'bitrate': 832000,
#          'content_type': 'video/mp4',
#          'url': 'https://video.twimg.com/amplify_video/1130665764460093440/vid/640x360/Cdy83_er5LtvIjZA.mp4?tag=12'}]},
#       'additional_media_info': {'monetizable': False}}]},
#    'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#    'source': '<a href="http://grabyo.com" rel="nofollow">Grabyo</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 3097539491,
#     'id_str': '3097539491',
#     'name': 'Central FOX Brasil',
#     'screen_name': 'CentralFoxBR',
#     'location': '',
#     'description': 'Noticiário oficial do @FOXSportsBrasil',
#     'url': 'https://t.co/DFcQOHKFxy',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/DFcQOHKFxy',
#         'expanded_url': 'http://www.foxsports.com.br',
#         'display_url': 'foxsports.com.br',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 131200,
#     'friends_count': 500,
#     'listed_count': 253,
#     'created_at': 'Thu Mar 19 20:03:41 +0000 2015',
#     'favourites_count': 6075,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': True,
#     'verified': True,
#     'statuses_count': 99686,
#     'lang': 'pt',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/967253138318200832/FM4be3An_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/967253138318200832/FM4be3An_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/3097539491/1537459498',
#     'profile_link_color': '3B94D9',
#     'profile_sidebar_border_color': '000000',
#     'profile_sidebar_fill_color': '000000',
#     'profile_text_color': '000000',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 2493,
#    'favorite_count': 7844,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'pt'},
#   'is_quote_status': False,
#   'retweet_count': 2493,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'pt'},
#  {'created_at': 'Mon May 27 06:57:18 +0000 2019',
#   'id': 1132903589188382723,
#   'id_str': '1132903589188382723',
#   'full_text': 'Após derrota para o Bahia, João Pedro foca na Sul-Americana https://t.co/Jw7iHtIjZ8',
#   'truncated': False,
#   'display_text_range': [0, 83],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/Jw7iHtIjZ8',
#      'expanded_url': 'https://www.gazetaesportiva.com/times/fluminense/apos-derrota-para-o-bahia-joao-pedro-foca-na-sul-americana/',
#      'display_url': 'gazetaesportiva.com/times/fluminen…',
#      'indices': [60, 83]}]},
#   'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1556325758,
#    'id_str': '1556325758',
#    'name': 'Flu Maior',
#    'screen_name': 'FLUMAIOR',
#    'location': 'Jamaica ( Iowa ).',
#    'description': 'Tricolor doente e brasileiro decente, papo reto...ST.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 3634,
#    'friends_count': 4066,
#    'listed_count': 13,
#    'created_at': 'Sat Jun 29 19:00:08 +0000 2013',
#    'favourites_count': 10026,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 23276,
#    'lang': 'pt',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '0A2E02',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1034433174691082240/H6qVlX-J_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1034433174691082240/H6qVlX-J_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1556325758/1518301755',
#    'profile_link_color': '06B300',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'pt'},
#  {'created_at': 'Mon May 27 06:56:54 +0000 2019',
#   'id': 1132903485933019136,
#   'id_str': '1132903485933019136',
#   'full_text': 'João Pedro lamenta chances perdidas e pede foco na Sul-Americana | LANCE! https://t.co/mGvOdwHmMV',
#   'truncated': False,
#   'display_text_range': [0, 97],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/mGvOdwHmMV',
#      'expanded_url': 'https://m.lance.com.br/fluminense/joao-pedro-lamenta-chances-perdidas-pede-foco-sul-americana.html',
#      'display_url': 'm.lance.com.br/fluminense/joa…',
#      'indices': [74, 97]}]},
#   'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1556325758,
#    'id_str': '1556325758',
#    'name': 'Flu Maior',
#    'screen_name': 'FLUMAIOR',
#    'location': 'Jamaica ( Iowa ).',
#    'description': 'Tricolor doente e brasileiro decente, papo reto...ST.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 3634,
#    'friends_count': 4066,
#    'listed_count': 13,
#    'created_at': 'Sat Jun 29 19:00:08 +0000 2013',
#    'favourites_count': 10026,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 23276,
#    'lang': 'pt',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '0A2E02',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': True,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1034433174691082240/H6qVlX-J_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1034433174691082240/H6qVlX-J_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1556325758/1518301755',
#    'profile_link_color': '06B300',
#    'profile_sidebar_border_color': 'FFFFFF',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'pt'}]

# %%
bsilva_tweets = [obj._json for obj in api.search(q="bruno silva fluminense", count=1000, tweet_mode="extended", since='2018-01-01')]

# %%
mg_client = MongoClient('localhost', 27017)

# %%
tweets_to_classify = mg_client.datapop.tweets_to_classify

# %%
result = tweets_to_classify.insert_many(jp_tweets)

# %%
result.inserted_ids
# Out:
# [ObjectId('5ceac65d878f5b34cdc326fa'),
#  ObjectId('5ceac65d878f5b34cdc326fb'),
#  ObjectId('5ceac65d878f5b34cdc326fc'),
#  ObjectId('5ceac65d878f5b34cdc326fd'),
#  ObjectId('5ceac65d878f5b34cdc326fe'),
#  ObjectId('5ceac65d878f5b34cdc326ff'),
#  ObjectId('5ceac65d878f5b34cdc32700'),
#  ObjectId('5ceac65d878f5b34cdc32701'),
#  ObjectId('5ceac65d878f5b34cdc32702'),
#  ObjectId('5ceac65d878f5b34cdc32703'),
#  ObjectId('5ceac65d878f5b34cdc32704'),
#  ObjectId('5ceac65d878f5b34cdc32705'),
#  ObjectId('5ceac65d878f5b34cdc32706'),
#  ObjectId('5ceac65d878f5b34cdc32707'),
#  ObjectId('5ceac65d878f5b34cdc32708'),
#  ObjectId('5ceac65d878f5b34cdc32709'),
#  ObjectId('5ceac65d878f5b34cdc3270a'),
#  ObjectId('5ceac65d878f5b34cdc3270b'),
#  ObjectId('5ceac65d878f5b34cdc3270c'),
#  ObjectId('5ceac65d878f5b34cdc3270d'),
#  ObjectId('5ceac65d878f5b34cdc3270e'),
#  ObjectId('5ceac65d878f5b34cdc3270f'),
#  ObjectId('5ceac65d878f5b34cdc32710'),
#  ObjectId('5ceac65d878f5b34cdc32711'),
#  ObjectId('5ceac65d878f5b34cdc32712'),
#  ObjectId('5ceac65d878f5b34cdc32713'),
#  ObjectId('5ceac65d878f5b34cdc32714'),
#  ObjectId('5ceac65d878f5b34cdc32715'),
#  ObjectId('5ceac65d878f5b34cdc32716'),
#  ObjectId('5ceac65d878f5b34cdc32717'),
#  ObjectId('5ceac65d878f5b34cdc32718'),
#  ObjectId('5ceac65d878f5b34cdc32719'),
#  ObjectId('5ceac65d878f5b34cdc3271a'),
#  ObjectId('5ceac65d878f5b34cdc3271b'),
#  ObjectId('5ceac65d878f5b34cdc3271c'),
#  ObjectId('5ceac65d878f5b34cdc3271d'),
#  ObjectId('5ceac65d878f5b34cdc3271e'),
#  ObjectId('5ceac65d878f5b34cdc3271f'),
#  ObjectId('5ceac65d878f5b34cdc32720'),
#  ObjectId('5ceac65d878f5b34cdc32721'),
#  ObjectId('5ceac65d878f5b34cdc32722'),
#  ObjectId('5ceac65d878f5b34cdc32723'),
#  ObjectId('5ceac65d878f5b34cdc32724'),
#  ObjectId('5ceac65d878f5b34cdc32725'),
#  ObjectId('5ceac65d878f5b34cdc32726'),
#  ObjectId('5ceac65d878f5b34cdc32727'),
#  ObjectId('5ceac65d878f5b34cdc32728'),
#  ObjectId('5ceac65d878f5b34cdc32729'),
#  ObjectId('5ceac65d878f5b34cdc3272a'),
#  ObjectId('5ceac65d878f5b34cdc3272b'),
#  ObjectId('5ceac65d878f5b34cdc3272c'),
#  ObjectId('5ceac65d878f5b34cdc3272d'),
#  ObjectId('5ceac65d878f5b34cdc3272e'),
#  ObjectId('5ceac65d878f5b34cdc3272f'),
#  ObjectId('5ceac65d878f5b34cdc32730'),
#  ObjectId('5ceac65d878f5b34cdc32731'),
#  ObjectId('5ceac65d878f5b34cdc32732'),
#  ObjectId('5ceac65d878f5b34cdc32733'),
#  ObjectId('5ceac65d878f5b34cdc32734'),
#  ObjectId('5ceac65d878f5b34cdc32735')]

# %%
tweets_to_classify.insert_many(bsilva_tweets)

# %%
import json

# %%
{str(obj['_id']): obj for obj in tweets_to_classify.aggregate([{'$sample': {'size': 10}}])}
# Out:
# {'5ce0b017955b29be97b58ef0': {'_id': ObjectId('5ce0b017955b29be97b58ef0'),
#   'created_at': 'Sun May 19 00:19:46 +0000 2019',
#   'id': 1129904442722181120,
#   'id_str': '1129904442722181120',
#   'full_text': 'RT @fredgol9: 🙏🏼🦊🔵 https://t.co/Urhv55aHca',
#   'truncated': False,
#   'display_text_range': [0, 42],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'fredgol9',
#      'name': 'Fred Guedes',
#      'id': 25073959,
#      'id_str': '25073959',
#      'indices': [3, 12]}],
#    'urls': [],
#    'media': [{'id': 1129838031018627072,
#      'id_str': '1129838031018627072',
#      'indices': [19, 42],
#      'media_url': 'http://pbs.twimg.com/media/D639s_yXkAABTIq.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/D639s_yXkAABTIq.jpg',
#      'url': 'https://t.co/Urhv55aHca',
#      'display_url': 'pic.twitter.com/Urhv55aHca',
#      'expanded_url': 'https://twitter.com/fredgol9/status/1129838037679124480/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 1000, 'h': 1000, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#       'large': {'w': 1000, 'h': 1000, 'resize': 'fit'}},
#      'source_status_id': 1129838037679124480,
#      'source_status_id_str': '1129838037679124480',
#      'source_user_id': 25073959,
#      'source_user_id_str': '25073959'}]},
#   'extended_entities': {'media': [{'id': 1129838031018627072,
#      'id_str': '1129838031018627072',
#      'indices': [19, 42],
#      'media_url': 'http://pbs.twimg.com/media/D639s_yXkAABTIq.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/D639s_yXkAABTIq.jpg',
#      'url': 'https://t.co/Urhv55aHca',
#      'display_url': 'pic.twitter.com/Urhv55aHca',
#      'expanded_url': 'https://twitter.com/fredgol9/status/1129838037679124480/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 1000, 'h': 1000, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#       'large': {'w': 1000, 'h': 1000, 'resize': 'fit'}},
#      'source_status_id': 1129838037679124480,
#      'source_status_id_str': '1129838037679124480',
#      'source_user_id': 25073959,
#      'source_user_id_str': '25073959'}]},
#   'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 570527329,
#    'id_str': '570527329',
#    'name': 'Galo Verdade',
#    'screen_name': 'Galoverdade',
#    'location': '',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 120,
#    'friends_count': 257,
#    'listed_count': 0,
#    'created_at': 'Fri May 04 04:19:38 +0000 2012',
#    'favourites_count': 11158,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 4225,
#    'lang': 'pt',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/2190927937/zYOliWzC_normal',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/2190927937/zYOliWzC_normal',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sat May 18 19:55:54 +0000 2019',
#    'id': 1129838037679124480,
#    'id_str': '1129838037679124480',
#    'full_text': '🙏🏼🦊🔵 https://t.co/Urhv55aHca',
#    'truncated': False,
#    'display_text_range': [0, 4],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [],
#     'media': [{'id': 1129838031018627072,
#       'id_str': '1129838031018627072',
#       'indices': [5, 28],
#       'media_url': 'http://pbs.twimg.com/media/D639s_yXkAABTIq.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/D639s_yXkAABTIq.jpg',
#       'url': 'https://t.co/Urhv55aHca',
#       'display_url': 'pic.twitter.com/Urhv55aHca',
#       'expanded_url': 'https://twitter.com/fredgol9/status/1129838037679124480/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1000, 'h': 1000, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#        'large': {'w': 1000, 'h': 1000, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1129838031018627072,
#       'id_str': '1129838031018627072',
#       'indices': [5, 28],
#       'media_url': 'http://pbs.twimg.com/media/D639s_yXkAABTIq.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/D639s_yXkAABTIq.jpg',
#       'url': 'https://t.co/Urhv55aHca',
#       'display_url': 'pic.twitter.com/Urhv55aHca',
#       'expanded_url': 'https://twitter.com/fredgol9/status/1129838037679124480/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1000, 'h': 1000, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#        'large': {'w': 1000, 'h': 1000, 'resize': 'fit'}}}]},
#    'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 25073959,
#     'id_str': '25073959',
#     'name': 'Fred Guedes',
#     'screen_name': 'fredgol9',
#     'location': 'Belo Horizonte, Brasil',
#     'description': 'Jogador do @cruzeiro',
#     'url': 'https://t.co/uMaNuld4gI',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/uMaNuld4gI',
#         'expanded_url': 'http://francismelo.com.br/fred',
#         'display_url': 'francismelo.com.br/fred',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1890163,
#     'friends_count': 136,
#     'listed_count': 3267,
#     'created_at': 'Wed Mar 18 13:47:07 +0000 2009',
#     'favourites_count': 43,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': True,
#     'statuses_count': 1605,
#     'lang': 'pt',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1001528060414496769/VgK5xS1g_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1001528060414496769/VgK5xS1g_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073959/1527617737',
#     'profile_link_color': '0A0A0A',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': '7D0D25',
#     'profile_text_color': '666666',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': True,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 40,
#    'favorite_count': 1446,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'und'},
#   'is_quote_status': False,
#   'retweet_count': 40,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'und'},
#  '5ce0b035955b29be97b58f34': {'_id': ObjectId('5ce0b035955b29be97b58f34'),
#   'created_at': 'Thu May 16 12:52:00 +0000 2019',
#   'id': 1129006584191782912,
#   'id_str': '1129006584191782912',
#   'full_text': 'Bruno Silva é submetido a artroscopia no joelho direito e deve receber alta nesta quinta https://t.co/a08jr9OSWd https://t.co/mQtioRTEqN',
#   'truncated': False,
#   'display_text_range': [0, 112],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [],
#    'urls': [{'url': 'https://t.co/a08jr9OSWd',
#      'expanded_url': 'http://glo.bo/2JG2TEN',
#      'display_url': 'glo.bo/2JG2TEN',
#      'indices': [89, 112]}],
#    'media': [{'id': 1129005675898654720,
#      'id_str': '1129005675898654720',
#      'indices': [113, 136],
#      'media_url': 'http://pbs.twimg.com/media/D6sIrjVW0AAhqNh.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/D6sIrjVW0AAhqNh.jpg',
#      'url': 'https://t.co/mQtioRTEqN',
#      'display_url': 'pic.twitter.com/mQtioRTEqN',
#      'expanded_url': 'https://twitter.com/globoesportecom/status/1129006584191782912/photo/1',
#      'type': 'photo',
#      'sizes': {'small': {'w': 680, 'h': 381, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 1200, 'h': 673, 'resize': 'fit'},
#       'large': {'w': 2048, 'h': 1148, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 1129005675898654720,
#      'id_str': '1129005675898654720',
#      'indices': [113, 136],
#      'media_url': 'http://pbs.twimg.com/media/D6sIrjVW0AAhqNh.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/D6sIrjVW0AAhqNh.jpg',
#      'url': 'https://t.co/mQtioRTEqN',
#      'display_url': 'pic.twitter.com/mQtioRTEqN',
#      'expanded_url': 'https://twitter.com/globoesportecom/status/1129006584191782912/photo/1',
#      'type': 'photo',
#      'sizes': {'small': {'w': 680, 'h': 381, 'resize': 'fit'},
#       'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 1200, 'h': 673, 'resize': 'fit'},
#       'large': {'w': 2048, 'h': 1148, 'resize': 'fit'}}}]},
#   'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#   'source': '<a href="https://about.twitter.com/products/tweetdeck" rel="nofollow">TweetDeck</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 10842792,
#    'id_str': '10842792',
#    'name': 'globoesportecom',
#    'screen_name': 'globoesportecom',
#    'location': 'Brasil',
#    'description': "'Se a bola soubesse o encanto que tem, não passaria a vida rolando de pé em pé' - Armando Nogueira",
#    'url': 'https://t.co/WuQudTDGQC',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/WuQudTDGQC',
#        'expanded_url': 'http://www.globoesporte.com',
#        'display_url': 'globoesporte.com',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 4357327,
#    'friends_count': 308,
#    'listed_count': 9479,
#    'created_at': 'Tue Dec 04 16:44:39 +0000 2007',
#    'favourites_count': 236,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': True,
#    'statuses_count': 265244,
#    'lang': 'pt',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '1F8A04',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1096546033377656832/jltzTJGS_normal.png',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1096546033377656832/jltzTJGS_normal.png',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/10842792/1550271960',
#    'profile_link_color': '0B7317',
#    'profile_sidebar_border_color': '087302',
#    'profile_sidebar_fill_color': 'E8FAE9',
#    'profile_text_color': '000000',
#    'profile_use_background_image': False,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 3,
#   'favorite_count': 59,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'pt'},
#  '5ce0b017955b29be97b58ee8': {'_id': ObjectId('5ce0b017955b29be97b58ee8'),
#   'created_at': 'Sun May 19 00:25:31 +0000 2019',
#   'id': 1129905891858440192,
#   'id_str': '1129905891858440192',
#   'full_text': '@fredgol9 Eu não vou tocar pra você se você estiver com dó - LIMA, Henrique.',
#   'truncated': False,
#   'display_text_range': [10, 76],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'fredgol9',
#      'name': 'Fred Guedes',
#      'id': 25073959,
#      'id_str': '25073959',
#      'indices': [0, 9]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': 1129838037679124480,
#   'in_reply_to_status_id_str': '1129838037679124480',
#   'in_reply_to_user_id': 25073959,
#   'in_reply_to_user_id_str': '25073959',
#   'in_reply_to_screen_name': 'fredgol9',
#   'user': {'id': 926112622684012544,
#    'id_str': '926112622684012544',
#    'name': '6 x 1 Copas do Brasil',
#    'screen_name': 'dooxalbuquerque',
#    'location': '',
#    'description': 'Existe 1 (um) grande clube na cidade!',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 9,
#    'friends_count': 31,
#    'listed_count': 0,
#    'created_at': 'Thu Nov 02 15:43:50 +0000 2017',
#    'favourites_count': 165,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 154,
#    'lang': 'pt',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/926585645652463618/tNVJ6Ufd_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/926585645652463618/tNVJ6Ufd_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/926112622684012544/1509750206',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'pt'},
#  '5ce0b017955b29be97b58ee3': {'_id': ObjectId('5ce0b017955b29be97b58ee3'),
#   'created_at': 'Sun May 19 00:29:59 +0000 2019',
#   'id': 1129907012295372800,
#   'id_str': '1129907012295372800',
#   'full_text': '@fredgol9 Vai toma no seu cu, filho da puta. Mercenário. Arrogante do caralho. Vai puta que te pariu.',
#   'truncated': False,
#   'display_text_range': [10, 101],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'fredgol9',
#      'name': 'Fred Guedes',
#      'id': 25073959,
#      'id_str': '25073959',
#      'indices': [0, 9]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': 1129838037679124480,
#   'in_reply_to_status_id_str': '1129838037679124480',
#   'in_reply_to_user_id': 25073959,
#   'in_reply_to_user_id_str': '25073959',
#   'in_reply_to_screen_name': 'fredgol9',
#   'user': {'id': 245990340,
#    'id_str': '245990340',
#    'name': 'Roger Wendell',
#    'screen_name': 'roger_wendell',
#    'location': 'Belo Horizonte, Brasil',
#    'description': '👻rogerwendell\n\n\n\n\n\n\n💙Cruzeiro',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 727,
#    'friends_count': 388,
#    'listed_count': 1,
#    'created_at': 'Tue Feb 01 22:10:15 +0000 2011',
#    'favourites_count': 12413,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 20449,
#    'lang': 'pt',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': '1A1B1F',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1128030471894577155/2ecNVw7P_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1128030471894577155/2ecNVw7P_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/245990340/1557811134',
#    'profile_link_color': '05F4FC',
#    'profile_sidebar_border_color': '181A1E',
#    'profile_sidebar_fill_color': '252429',
#    'profile_text_color': '666666',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'pt'},
#  '5ce0b017955b29be97b58ed1': {'_id': ObjectId('5ce0b017955b29be97b58ed1'),
#   'created_at': 'Sun May 19 01:02:09 +0000 2019',
#   'id': 1129915109529313280,
#   'id_str': '1129915109529313280',
#   'full_text': 'RT @CruzeiroVerdad2: @fredgol9 Pega sua malinha e seu celular e vai fazer stories em outro lugar. https://t.co/S6rcQH8reX',
#   'truncated': False,
#   'display_text_range': [0, 121],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'CruzeiroVerdad2',
#      'name': 'CruzeiroVerdade',
#      'id': 1068201932488101888,
#      'id_str': '1068201932488101888',
#      'indices': [3, 19]},
#     {'screen_name': 'fredgol9',
#      'name': 'Fred Guedes',
#      'id': 25073959,
#      'id_str': '25073959',
#      'indices': [21, 30]}],
#    'urls': [],
#    'media': [{'id': 1129905588543135744,
#      'id_str': '1129905588543135744',
#      'indices': [98, 121],
#      'media_url': 'http://pbs.twimg.com/media/D647JXLXoAA5psm.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/D647JXLXoAA5psm.jpg',
#      'url': 'https://t.co/S6rcQH8reX',
#      'display_url': 'pic.twitter.com/S6rcQH8reX',
#      'expanded_url': 'https://twitter.com/CruzeiroVerdad2/status/1129905600803024896/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 511, 'h': 480, 'resize': 'fit'},
#       'small': {'w': 511, 'h': 480, 'resize': 'fit'},
#       'medium': {'w': 511, 'h': 480, 'resize': 'fit'}},
#      'source_status_id': 1129905600803024896,
#      'source_status_id_str': '1129905600803024896',
#      'source_user_id': 1068201932488101888,
#      'source_user_id_str': '1068201932488101888'}]},
#   'extended_entities': {'media': [{'id': 1129905588543135744,
#      'id_str': '1129905588543135744',
#      'indices': [98, 121],
#      'media_url': 'http://pbs.twimg.com/media/D647JXLXoAA5psm.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/D647JXLXoAA5psm.jpg',
#      'url': 'https://t.co/S6rcQH8reX',
#      'display_url': 'pic.twitter.com/S6rcQH8reX',
#      'expanded_url': 'https://twitter.com/CruzeiroVerdad2/status/1129905600803024896/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 511, 'h': 480, 'resize': 'fit'},
#       'small': {'w': 511, 'h': 480, 'resize': 'fit'},
#       'medium': {'w': 511, 'h': 480, 'resize': 'fit'}},
#      'source_status_id': 1129905600803024896,
#      'source_status_id_str': '1129905600803024896',
#      'source_user_id': 1068201932488101888,
#      'source_user_id_str': '1068201932488101888'}]},
#   'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 2842050448,
#    'id_str': '2842050448',
#    'name': 'Júnior',
#    'screen_name': 'gejr85',
#    'location': 'Belo Horizonte, Brasil',
#    'description': '...livrai-me de todo o mal. Amém!🙏 Deus, estais sempre comigo. Cruzeirense, CEC, Cruzeiro💙💙💙💙💙, Mineiro.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 814,
#    'friends_count': 1834,
#    'listed_count': 1,
#    'created_at': 'Thu Oct 23 16:21:51 +0000 2014',
#    'favourites_count': 6060,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 5501,
#    'lang': 'pt',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/968540376163287042/xoXrhMRe_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/968540376163287042/xoXrhMRe_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2842050448/1519598839',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sun May 19 00:24:22 +0000 2019',
#    'id': 1129905600803024896,
#    'id_str': '1129905600803024896',
#    'full_text': '@fredgol9 Pega sua malinha e seu celular e vai fazer stories em outro lugar. https://t.co/S6rcQH8reX',
#    'truncated': False,
#    'display_text_range': [10, 76],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [{'screen_name': 'fredgol9',
#       'name': 'Fred Guedes',
#       'id': 25073959,
#       'id_str': '25073959',
#       'indices': [0, 9]}],
#     'urls': [],
#     'media': [{'id': 1129905588543135744,
#       'id_str': '1129905588543135744',
#       'indices': [77, 100],
#       'media_url': 'http://pbs.twimg.com/media/D647JXLXoAA5psm.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/D647JXLXoAA5psm.jpg',
#       'url': 'https://t.co/S6rcQH8reX',
#       'display_url': 'pic.twitter.com/S6rcQH8reX',
#       'expanded_url': 'https://twitter.com/CruzeiroVerdad2/status/1129905600803024896/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 511, 'h': 480, 'resize': 'fit'},
#        'small': {'w': 511, 'h': 480, 'resize': 'fit'},
#        'medium': {'w': 511, 'h': 480, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1129905588543135744,
#       'id_str': '1129905588543135744',
#       'indices': [77, 100],
#       'media_url': 'http://pbs.twimg.com/media/D647JXLXoAA5psm.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/D647JXLXoAA5psm.jpg',
#       'url': 'https://t.co/S6rcQH8reX',
#       'display_url': 'pic.twitter.com/S6rcQH8reX',
#       'expanded_url': 'https://twitter.com/CruzeiroVerdad2/status/1129905600803024896/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'large': {'w': 511, 'h': 480, 'resize': 'fit'},
#        'small': {'w': 511, 'h': 480, 'resize': 'fit'},
#        'medium': {'w': 511, 'h': 480, 'resize': 'fit'}}}]},
#    'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': 1129838037679124480,
#    'in_reply_to_status_id_str': '1129838037679124480',
#    'in_reply_to_user_id': 25073959,
#    'in_reply_to_user_id_str': '25073959',
#    'in_reply_to_screen_name': 'fredgol9',
#    'user': {'id': 1068201932488101888,
#     'id_str': '1068201932488101888',
#     'name': 'CruzeiroVerdade',
#     'screen_name': 'CruzeiroVerdad2',
#     'location': 'Patos de Minas, Brasil',
#     'description': 'Aqui, somente a verdade sobre o Cruzeiro!',
#     'url': None,
#     'entities': {'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 7011,
#     'friends_count': 5872,
#     'listed_count': 6,
#     'created_at': 'Thu Nov 29 17:56:01 +0000 2018',
#     'favourites_count': 2518,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': False,
#     'statuses_count': 3773,
#     'lang': 'en',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': 'F5F8FA',
#     'profile_background_image_url': None,
#     'profile_background_image_url_https': None,
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1068203166435602432/c6D2MQuj_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1068203166435602432/c6D2MQuj_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1068201932488101888/1543611034',
#     'profile_link_color': '1DA1F2',
#     'profile_sidebar_border_color': 'C0DEED',
#     'profile_sidebar_fill_color': 'DDEEF6',
#     'profile_text_color': '333333',
#     'profile_use_background_image': True,
#     'has_extended_profile': True,
#     'default_profile': True,
#     'default_profile_image': False,
#     'following': False,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 3,
#    'favorite_count': 9,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'pt'},
#   'is_quote_status': False,
#   'retweet_count': 3,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'pt'},
#  '5ce0b017955b29be97b58f15': {'_id': ObjectId('5ce0b017955b29be97b58f15'),
#   'created_at': 'Sun May 19 00:03:59 +0000 2019',
#   'id': 1129900470129102848,
#   'id_str': '1129900470129102848',
#   'full_text': '@fredgol9 te amo, fredão!',
#   'truncated': False,
#   'display_text_range': [10, 25],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'fredgol9',
#      'name': 'Fred Guedes',
#      'id': 25073959,
#      'id_str': '25073959',
#      'indices': [0, 9]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'in_reply_to_status_id': 1129838037679124480,
#   'in_reply_to_status_id_str': '1129838037679124480',
#   'in_reply_to_user_id': 25073959,
#   'in_reply_to_user_id_str': '25073959',
#   'in_reply_to_screen_name': 'fredgol9',
#   'user': {'id': 440912402,
#    'id_str': '440912402',
#    'name': 'VAMOS FLUZÃO!',
#    'screen_name': 'thiagofredgol',
#    'location': '',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 139,
#    'friends_count': 293,
#    'listed_count': 1,
#    'created_at': 'Mon Dec 19 15:01:13 +0000 2011',
#    'favourites_count': 4794,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 1047,
#    'lang': 'pt',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/613497410640314372/F6lfSl0T_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/613497410640314372/F6lfSl0T_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/440912402/1435104156',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'pt'},
#  '5ce0b017955b29be97b58efd': {'_id': ObjectId('5ce0b017955b29be97b58efd'),
#   'created_at': 'Sun May 19 00:12:49 +0000 2019',
#   'id': 1129902694724980736,
#   'id_str': '1129902694724980736',
#   'full_text': 'Não sei quem me ilude mais, se é a mina da quebrada ou um tal de  és @fredgol9 @cartolafc https://t.co/mfz2m2POB2',
#   'truncated': False,
#   'display_text_range': [0, 89],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'fredgol9',
#      'name': 'Fred Guedes',
#      'id': 25073959,
#      'id_str': '25073959',
#      'indices': [69, 78]},
#     {'screen_name': 'cartolafc',
#      'name': 'Cartola FC',
#      'id': 10075202,
#      'id_str': '10075202',
#      'indices': [79, 89]}],
#    'urls': [],
#    'media': [{'id': 1129902684029497350,
#      'id_str': '1129902684029497350',
#      'indices': [90, 113],
#      'media_url': 'http://pbs.twimg.com/media/D644gTBWsAY82xs.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/D644gTBWsAY82xs.jpg',
#      'url': 'https://t.co/mfz2m2POB2',
#      'display_url': 'pic.twitter.com/mfz2m2POB2',
#      'expanded_url': 'https://twitter.com/Marciio_Siilva7/status/1129902694724980736/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 750, 'h': 1334, 'resize': 'fit'},
#       'medium': {'w': 675, 'h': 1200, 'resize': 'fit'},
#       'small': {'w': 382, 'h': 680, 'resize': 'fit'}}}]},
#   'extended_entities': {'media': [{'id': 1129902684029497350,
#      'id_str': '1129902684029497350',
#      'indices': [90, 113],
#      'media_url': 'http://pbs.twimg.com/media/D644gTBWsAY82xs.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/D644gTBWsAY82xs.jpg',
#      'url': 'https://t.co/mfz2m2POB2',
#      'display_url': 'pic.twitter.com/mfz2m2POB2',
#      'expanded_url': 'https://twitter.com/Marciio_Siilva7/status/1129902694724980736/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'large': {'w': 750, 'h': 1334, 'resize': 'fit'},
#       'medium': {'w': 675, 'h': 1200, 'resize': 'fit'},
#       'small': {'w': 382, 'h': 680, 'resize': 'fit'}}}]},
#   'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 1117933916084682752,
#    'id_str': '1117933916084682752',
#    'name': 'Márcio Silva',
#    'screen_name': 'Marciio_Siilva7',
#    'location': 'Niterói, Brasil',
#    'description': 'Profissional de Educação Física. “Levo no peito e na alma um sentimento chamado Flamengo”. @Flamengo ♥️⚫️',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 18,
#    'friends_count': 38,
#    'listed_count': 0,
#    'created_at': 'Mon Apr 15 23:33:10 +0000 2019',
#    'favourites_count': 134,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': False,
#    'verified': False,
#    'statuses_count': 28,
#    'lang': 'en',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1129165053813501952/ZyI-mUdd_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1129165053813501952/ZyI-mUdd_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/1117933916084682752/1555690567',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'pt'},
#  '5ce0b017955b29be97b58ee6': {'_id': ObjectId('5ce0b017955b29be97b58ee6'),
#   'created_at': 'Sun May 19 00:26:24 +0000 2019',
#   'id': 1129906111795138560,
#   'id_str': '1129906111795138560',
#   'full_text': '@fredgol9 Cone de merda. Som do Cruzeiro, seu bosta!!!',
#   'truncated': False,
#   'display_text_range': [10, 54],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'fredgol9',
#      'name': 'Fred Guedes',
#      'id': 25073959,
#      'id_str': '25073959',
#      'indices': [0, 9]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com" rel="nofollow">Twitter Web Client</a>',
#   'in_reply_to_status_id': 1129838037679124480,
#   'in_reply_to_status_id_str': '1129838037679124480',
#   'in_reply_to_user_id': 25073959,
#   'in_reply_to_user_id_str': '25073959',
#   'in_reply_to_screen_name': 'fredgol9',
#   'user': {'id': 2301882679,
#    'id_str': '2301882679',
#    'name': 'Barcelos Cruzeiro',
#    'screen_name': 'BarcelosCEC',
#    'location': '',
#    'description': '',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 133,
#    'friends_count': 666,
#    'listed_count': 3,
#    'created_at': 'Mon Jan 20 19:00:32 +0000 2014',
#    'favourites_count': 2269,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 5868,
#    'lang': 'pt',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1049396868076199942/PxuTujI-_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1049396868076199942/PxuTujI-_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/2301882679/1471083351',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'pt'},
#  '5ce0b017955b29be97b58f17': {'_id': ObjectId('5ce0b017955b29be97b58f17'),
#   'created_at': 'Sun May 19 00:03:50 +0000 2019',
#   'id': 1129900432401346561,
#   'id_str': '1129900432401346561',
#   'full_text': '@fredgol9 Lixooooooo. Nunca será ídolo em lugar algum. Espero que o cruzeiro atrapalhe sua carreira colo vc está atrapalhando o cruzeiro.',
#   'truncated': False,
#   'display_text_range': [10, 137],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'fredgol9',
#      'name': 'Fred Guedes',
#      'id': 25073959,
#      'id_str': '25073959',
#      'indices': [0, 9]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': 1129838037679124480,
#   'in_reply_to_status_id_str': '1129838037679124480',
#   'in_reply_to_user_id': 25073959,
#   'in_reply_to_user_id_str': '25073959',
#   'in_reply_to_screen_name': 'fredgol9',
#   'user': {'id': 80578938,
#    'id_str': '80578938',
#    'name': 'JUNINHO',
#    'screen_name': 'figueredojunior',
#    'location': 'Belo Horizonte',
#    'description': 'Muito sol, com tempestades corriqueiras. Deus amor maior, cruzeiro incondicional. maior de minas. 🙅\u200d♂️',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1325,
#    'friends_count': 1351,
#    'listed_count': 3,
#    'created_at': 'Wed Oct 07 13:39:55 +0000 2009',
#    'favourites_count': 10195,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 10799,
#    'lang': 'pt',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1031190285475344384/IL2D1MGs_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1031190285475344384/IL2D1MGs_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/80578938/1492055502',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'pt'},
#  '5ce0b017955b29be97b58ede': {'_id': ObjectId('5ce0b017955b29be97b58ede'),
#   'created_at': 'Sun May 19 00:36:50 +0000 2019',
#   'id': 1129908737387450368,
#   'id_str': '1129908737387450368',
#   'full_text': '@CruzeiroVerdad2 @fredgol9 AtleticoVerdade vc devia chamar. Desculpe.',
#   'truncated': False,
#   'display_text_range': [27, 69],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'CruzeiroVerdad2',
#      'name': 'CruzeiroVerdade',
#      'id': 1068201932488101888,
#      'id_str': '1068201932488101888',
#      'indices': [0, 16]},
#     {'screen_name': 'fredgol9',
#      'name': 'Fred Guedes',
#      'id': 25073959,
#      'id_str': '25073959',
#      'indices': [17, 26]}],
#    'urls': []},
#   'metadata': {'iso_language_code': 'pt', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>',
#   'in_reply_to_status_id': 1129905600803024896,
#   'in_reply_to_status_id_str': '1129905600803024896',
#   'in_reply_to_user_id': 1068201932488101888,
#   'in_reply_to_user_id_str': '1068201932488101888',
#   'in_reply_to_screen_name': 'CruzeiroVerdad2',
#   'user': {'id': 71150705,
#    'id_str': '71150705',
#    'name': 'Fred Fox',
#    'screen_name': 'fredcruzeiro19',
#    'location': 'Brasil',
#    'description': 'Comentarista parcial.',
#    'url': None,
#    'entities': {'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 1155,
#    'friends_count': 1326,
#    'listed_count': 1,
#    'created_at': 'Thu Sep 03 02:39:37 +0000 2009',
#    'favourites_count': 1350,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 1475,
#    'lang': 'pt',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'C0DEED',
#    'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme1/bg.png',
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1128965923900153856/xLUFase6_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1128965923900153856/xLUFase6_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/71150705/1552557937',
#    'profile_link_color': '1B95E0',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': False,
#    'default_profile': False,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'is_quote_status': False,
#   'retweet_count': 0,
#   'favorite_count': 2,
#   'favorited': False,
#   'retweeted': False,
#   'lang': 'pt'}}

# %%
mg_client = MongoClient('localhost', 27017)
tweets = mg_client.datapop.tweets_to_classify

for i in tweets.aggregate([{'$sample': {'size': 1}}]):
    #print("{} ||| ".format(i))
    #print(type(i))
    #print(i.pop('_id', None))
    #print(i)
    pass

#tweets.aggregate([{'$sample': {'size': 1}}])

# %%
{str(obj['_id']): {i:obj[i] for i in obj if i != '_id'} for obj in tweets.aggregate([{'$sample': {'size': 1}}])}
# Out:
# {'5ce0b017955b29be97b58ef6': {'created_at': 'Sun May 19 00:15:41 +0000 2019',
#   'id': 1129903414270398466,
#   'id_str': '1129903414270398466',
#   'full_text': 'RT @fredgol9: 🙏🏼🦊🔵 https://t.co/Urhv55aHca',
#   'truncated': False,
#   'display_text_range': [0, 42],
#   'entities': {'hashtags': [],
#    'symbols': [],
#    'user_mentions': [{'screen_name': 'fredgol9',
#      'name': 'Fred Guedes',
#      'id': 25073959,
#      'id_str': '25073959',
#      'indices': [3, 12]}],
#    'urls': [],
#    'media': [{'id': 1129838031018627072,
#      'id_str': '1129838031018627072',
#      'indices': [19, 42],
#      'media_url': 'http://pbs.twimg.com/media/D639s_yXkAABTIq.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/D639s_yXkAABTIq.jpg',
#      'url': 'https://t.co/Urhv55aHca',
#      'display_url': 'pic.twitter.com/Urhv55aHca',
#      'expanded_url': 'https://twitter.com/fredgol9/status/1129838037679124480/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 1000, 'h': 1000, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#       'large': {'w': 1000, 'h': 1000, 'resize': 'fit'}},
#      'source_status_id': 1129838037679124480,
#      'source_status_id_str': '1129838037679124480',
#      'source_user_id': 25073959,
#      'source_user_id_str': '25073959'}]},
#   'extended_entities': {'media': [{'id': 1129838031018627072,
#      'id_str': '1129838031018627072',
#      'indices': [19, 42],
#      'media_url': 'http://pbs.twimg.com/media/D639s_yXkAABTIq.jpg',
#      'media_url_https': 'https://pbs.twimg.com/media/D639s_yXkAABTIq.jpg',
#      'url': 'https://t.co/Urhv55aHca',
#      'display_url': 'pic.twitter.com/Urhv55aHca',
#      'expanded_url': 'https://twitter.com/fredgol9/status/1129838037679124480/photo/1',
#      'type': 'photo',
#      'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#       'medium': {'w': 1000, 'h': 1000, 'resize': 'fit'},
#       'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#       'large': {'w': 1000, 'h': 1000, 'resize': 'fit'}},
#      'source_status_id': 1129838037679124480,
#      'source_status_id_str': '1129838037679124480',
#      'source_user_id': 25073959,
#      'source_user_id_str': '25073959'}]},
#   'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#   'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#   'in_reply_to_status_id': None,
#   'in_reply_to_status_id_str': None,
#   'in_reply_to_user_id': None,
#   'in_reply_to_user_id_str': None,
#   'in_reply_to_screen_name': None,
#   'user': {'id': 902324017981513728,
#    'id_str': '902324017981513728',
#    'name': 'Lucas',
#    'screen_name': 'lucs_ffc1',
#    'location': '',
#    'description': 'Tricolor, 20',
#    'url': 'https://t.co/x6mDq861rw',
#    'entities': {'url': {'urls': [{'url': 'https://t.co/x6mDq861rw',
#        'expanded_url': 'https://www.instagram.com/lucsmeloo/',
#        'display_url': 'instagram.com/lucsmeloo/',
#        'indices': [0, 23]}]},
#     'description': {'urls': []}},
#    'protected': False,
#    'followers_count': 4694,
#    'friends_count': 3907,
#    'listed_count': 8,
#    'created_at': 'Tue Aug 29 00:16:25 +0000 2017',
#    'favourites_count': 24059,
#    'utc_offset': None,
#    'time_zone': None,
#    'geo_enabled': True,
#    'verified': False,
#    'statuses_count': 30422,
#    'lang': 'pt',
#    'contributors_enabled': False,
#    'is_translator': False,
#    'is_translation_enabled': False,
#    'profile_background_color': 'F5F8FA',
#    'profile_background_image_url': None,
#    'profile_background_image_url_https': None,
#    'profile_background_tile': False,
#    'profile_image_url': 'http://pbs.twimg.com/profile_images/1103764571838390272/v_iGGraO_normal.jpg',
#    'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1103764571838390272/v_iGGraO_normal.jpg',
#    'profile_banner_url': 'https://pbs.twimg.com/profile_banners/902324017981513728/1511537887',
#    'profile_link_color': '1DA1F2',
#    'profile_sidebar_border_color': 'C0DEED',
#    'profile_sidebar_fill_color': 'DDEEF6',
#    'profile_text_color': '333333',
#    'profile_use_background_image': True,
#    'has_extended_profile': True,
#    'default_profile': True,
#    'default_profile_image': False,
#    'following': False,
#    'follow_request_sent': False,
#    'notifications': False,
#    'translator_type': 'none'},
#   'geo': None,
#   'coordinates': None,
#   'place': None,
#   'contributors': None,
#   'retweeted_status': {'created_at': 'Sat May 18 19:55:54 +0000 2019',
#    'id': 1129838037679124480,
#    'id_str': '1129838037679124480',
#    'full_text': '🙏🏼🦊🔵 https://t.co/Urhv55aHca',
#    'truncated': False,
#    'display_text_range': [0, 4],
#    'entities': {'hashtags': [],
#     'symbols': [],
#     'user_mentions': [],
#     'urls': [],
#     'media': [{'id': 1129838031018627072,
#       'id_str': '1129838031018627072',
#       'indices': [5, 28],
#       'media_url': 'http://pbs.twimg.com/media/D639s_yXkAABTIq.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/D639s_yXkAABTIq.jpg',
#       'url': 'https://t.co/Urhv55aHca',
#       'display_url': 'pic.twitter.com/Urhv55aHca',
#       'expanded_url': 'https://twitter.com/fredgol9/status/1129838037679124480/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1000, 'h': 1000, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#        'large': {'w': 1000, 'h': 1000, 'resize': 'fit'}}}]},
#    'extended_entities': {'media': [{'id': 1129838031018627072,
#       'id_str': '1129838031018627072',
#       'indices': [5, 28],
#       'media_url': 'http://pbs.twimg.com/media/D639s_yXkAABTIq.jpg',
#       'media_url_https': 'https://pbs.twimg.com/media/D639s_yXkAABTIq.jpg',
#       'url': 'https://t.co/Urhv55aHca',
#       'display_url': 'pic.twitter.com/Urhv55aHca',
#       'expanded_url': 'https://twitter.com/fredgol9/status/1129838037679124480/photo/1',
#       'type': 'photo',
#       'sizes': {'thumb': {'w': 150, 'h': 150, 'resize': 'crop'},
#        'medium': {'w': 1000, 'h': 1000, 'resize': 'fit'},
#        'small': {'w': 680, 'h': 680, 'resize': 'fit'},
#        'large': {'w': 1000, 'h': 1000, 'resize': 'fit'}}}]},
#    'metadata': {'iso_language_code': 'und', 'result_type': 'recent'},
#    'source': '<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>',
#    'in_reply_to_status_id': None,
#    'in_reply_to_status_id_str': None,
#    'in_reply_to_user_id': None,
#    'in_reply_to_user_id_str': None,
#    'in_reply_to_screen_name': None,
#    'user': {'id': 25073959,
#     'id_str': '25073959',
#     'name': 'Fred Guedes',
#     'screen_name': 'fredgol9',
#     'location': 'Belo Horizonte, Brasil',
#     'description': 'Jogador do @cruzeiro',
#     'url': 'https://t.co/uMaNuld4gI',
#     'entities': {'url': {'urls': [{'url': 'https://t.co/uMaNuld4gI',
#         'expanded_url': 'http://francismelo.com.br/fred',
#         'display_url': 'francismelo.com.br/fred',
#         'indices': [0, 23]}]},
#      'description': {'urls': []}},
#     'protected': False,
#     'followers_count': 1890163,
#     'friends_count': 136,
#     'listed_count': 3267,
#     'created_at': 'Wed Mar 18 13:47:07 +0000 2009',
#     'favourites_count': 43,
#     'utc_offset': None,
#     'time_zone': None,
#     'geo_enabled': False,
#     'verified': True,
#     'statuses_count': 1605,
#     'lang': 'pt',
#     'contributors_enabled': False,
#     'is_translator': False,
#     'is_translation_enabled': False,
#     'profile_background_color': '000000',
#     'profile_background_image_url': 'http://abs.twimg.com/images/themes/theme9/bg.gif',
#     'profile_background_image_url_https': 'https://abs.twimg.com/images/themes/theme9/bg.gif',
#     'profile_background_tile': False,
#     'profile_image_url': 'http://pbs.twimg.com/profile_images/1001528060414496769/VgK5xS1g_normal.jpg',
#     'profile_image_url_https': 'https://pbs.twimg.com/profile_images/1001528060414496769/VgK5xS1g_normal.jpg',
#     'profile_banner_url': 'https://pbs.twimg.com/profile_banners/25073959/1527617737',
#     'profile_link_color': '0A0A0A',
#     'profile_sidebar_border_color': 'FFFFFF',
#     'profile_sidebar_fill_color': '7D0D25',
#     'profile_text_color': '666666',
#     'profile_use_background_image': False,
#     'has_extended_profile': False,
#     'default_profile': False,
#     'default_profile_image': False,
#     'following': True,
#     'follow_request_sent': False,
#     'notifications': False,
#     'translator_type': 'none'},
#    'geo': None,
#    'coordinates': None,
#    'place': None,
#    'contributors': None,
#    'is_quote_status': False,
#    'retweet_count': 40,
#    'favorite_count': 1446,
#    'favorited': False,
#    'retweeted': False,
#    'possibly_sensitive': False,
#    'lang': 'und'},
#   'is_quote_status': False,
#   'retweet_count': 40,
#   'favorite_count': 0,
#   'favorited': False,
#   'retweeted': False,
#   'possibly_sensitive': False,
#   'lang': 'und'}}

# %%
{i.pop('_id', None) for i in tweets.aggregate([{'$sample': {'size': 1}}])}
# Out:
# {ObjectId('5ce0b017955b29be97b58ee3')}
